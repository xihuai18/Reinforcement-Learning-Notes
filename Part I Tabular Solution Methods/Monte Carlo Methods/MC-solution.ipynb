# %% [markdown]
# ### MC Solution
#
# #### 5.1
# **Answer**
# + Because the value of 20 and 21 is likelu to win.
# + The dealer has a ace, which has big influence.
# + Because it is less possible to go bust.
#
# #### 5.2
# **Answer**
#
# The results are expected to be the same, because in this game, there is no state that can appear twice.
#
# #### 5.3
# **Answer**
#
# A chain just like the one given in teh textbook.
#
# #### 5.4
# **Answer**
# $$
#     Q(S_{t},A_{t}) \leftarrow \frac{n-1}{n}Q(S_{t},A_{t})+\frac{1}{n}G
# $$
#
# #### 5.5
# **Answer**
#
# (how to use p?)
# + first-visit: 10
# + every-visis: 5.5
#
# #### 5.6
# **Answer**
#
#
# $$
#     Q(s,a) \doteq \frac{\sum_{t \in \tau(s)}p_{t:T(t)-1}G_{t}}{\sum_{t \in \tau(s)}p_{t:T(t)-1}}
# $$
#
# #### 5.7
# **Answer**
#
# In the exploration process, the probability in the numerator is so small.
#
# #### 5.8
# **Answer**
#
# Yes, in every-visit MC, the sum is even larger.
#
# #### 5.9
# **Answer**
# $$
# \begin{align*}
# C(S_{t}) &= C(S_{t}) + 1 \\
# V(S_{t}) &= V(S_{t}) + \frac{1}{C(S_{t})}[G_{t}-V(S_{t})
# \end{align*}
# $$
#
# #### 5.10
# **Answer**
# $$
#     \begin{align*}
#     C_{n+1} &= \sum_{k=1}^{n}W_{k} \\
#     V_{n+1} &= \frac{\sum_{k=1}^{n}W_{k}G_{k}}{C_{n+1}}\\
#     C_{n+1}V_{n+1} &= C_{n}V_{n}+W_{n}G_{n} \\
#               &= (C_{n+1}-W{n})V_{n} + W_{n}G_{n} \\
#               &= C_{n+1}V_{n} + W_{n}(G_{n}-V_{n}) \\
#     V_{n+1} &= V_{n}+\frac{W_{n}}{C_{n+1}}(G_{n}-V_{n})
#     \end{align*}
# $$
#
# #### 5.11
#
# Because the policy $\pi$ is deterministic, $\pi(A_t|S_t)$ is 1.
#
# #### 5.12

# %% [markdown]
# **Answer**

# %% [markdown]
# #### 5.13
# **Answer**
# Combine (5.13), the expectation of the other terms are 1
#
#
# #### 5.14
# **Answer**
# Substitude V(s) for Q(s,a) is enough.
#
# a sub loop:
# initialze:
# $$
#     \begin{align*}
#         S &\leftarrow 0 \\
#         P &\leftarrow 1 \\
#         GG &\leftarrow 1 \\
#     \end{align*}
# $$
# loop:
# $$
#     \begin{align*}
#         P &= P\frac{1}{b(A_{t}|S_{t})} \\
#         GG &= GG\times\gamma \\
#         S &= S+GG\times P
#     \end{align*}
# $$
# outer loop:
# $$
#     \begin{align*}
#         P &= P\frac{1}{b(A_{T}|S_{T})} \\
#         GG &= GG\times\gamma \\
#         W &= (1-\gamma)S + GG\times P
#     \end{align*}
# $$
